# %% [markdown]
# <a href="https://colab.research.google.com/github/Danish-2025/data_science_v1/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science
